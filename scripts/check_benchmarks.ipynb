# %%
import pandas as pd
import seaborn as sb

# %%
BENCHMARKS_PATH = "out.csv"

# %%
df = pd.read_csv(BENCHMARKS_PATH)
df.head(10)

# %% [markdown]
# ## O(n)
#
# Let's check first how both methods scale with different numbers

# %%
sb.lineplot(
    data=df,
    x="first",
    y="time",
    hue="name"
)
